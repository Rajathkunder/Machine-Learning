# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score

# Load the dataset
df = pd.read_csv("ccpp.csv")

# Checking for null values and the shape of the dataset
print(df.isnull().sum())
print(df.shape)

# Splitting features and target variable
X = df.drop(['PE'], axis=1).values
y = df['PE'].values

# Normalizing the features
scaler = StandardScaler()
X = scaler.fit_transform(X)

# Splitting the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# Adding a column of ones to X_train and X_test for the intercept term
X_train = np.c_[np.ones(X_train.shape[0]), X_train]
X_test = np.c_[np.ones(X_test.shape[0]), X_test]

# Gradient Descent function
def gradient_descent(X, y, learning_rate=0.01, iterations=1000):
    m = X.shape[0]
    n = X.shape[1]
    theta = np.zeros(n)
    for i in range(iterations):
        y_pred = np.dot(X, theta)
        error = y_pred - y
        gradient = (1/m) * np.dot(X.T, error)
        theta -= learning_rate * gradient
        if i % 100 == 0:  # Print progress every 100 iterations
            cost = (1/(2*m)) * np.dot(error.T, error)
            print(f"Iteration {i+1}: Cost {cost:.4f}")
    return theta

# Train the model using Gradient Descent
learning_rate = 0.01
iterations = 1000
theta = gradient_descent(X_train, y_train, learning_rate, iterations)

# Predict on the test set
y_pred = np.dot(X_test, theta)

# Evaluate the model
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"Mean Squared Error: {mse:.2f}")
print(f"R-Squared: {r2:.2f}")

# Coefficients and Intercept
print(f"Coefficients: {theta[1:]}")
print(f"Intercept: {theta[0]}")

# Plotting Actual vs Predicted values
plt.scatter(y_test, y_pred)
plt.plot([min(y_test), max(y_test)], [min(y_pred), max(y_pred)], color='red')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.title('Actual vs Predicted Values')
plt.show()
# Out:
# AT    0
# V     0
# AP    0
# RH    0
# PE    0
# dtype: int64
# (9568, 5)
# Iteration 1: Cost 103354.3781
# Iteration 101: Cost 13850.2816
# Iteration 201: Cost 1870.0313
# Iteration 301: Cost 263.0251
# Iteration 401: Cost 46.7889
# Iteration 501: Cost 17.2775
# Iteration 601: Cost 12.9375
# Iteration 701: Cost 12.0545
# Iteration 801: Cost 11.6938
# Iteration 901: Cost 11.4490
# Mean Squared Error: 22.22
# R-Squared: 0.92
# Coefficients: [-11.6467159   -5.23593255   1.00170921  -1.27750087]
# Intercept: 454.3572209961183

# %%
#iteration 1
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

X_train = np.c_[np.ones(X_train.shape[0]), X_train]
X_test = np.c_[np.ones(X_test.shape[0]), X_test]


def gradient_descent(X, y, learning_rate=0.01, iterations=1000):
    m = X.shape[0]
    n = X.shape[1]
    theta = np.zeros(n)
    for i in range(iterations):
        y_pred = np.dot(X, theta)
        error = y_pred - y
        gradient = (1/m) * np.dot(X.T, error)
        theta -= learning_rate * gradient
        if i % 100 == 0:  
            cost = (1/(2*m)) * np.dot(error.T, error)
            print(f"Iteration {i+1}: Cost {cost:.4f}")
    return theta

learning_rate = 0.01
iterations = 1000
theta = gradient_descent(X_train, y_train, learning_rate, iterations)


y_pred = np.dot(X_test, theta)

mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"Mean Squared Error: {mse:.2f}")
print(f"R-Squared: {r2:.2f}")

print(f"Coefficients: {theta[1:]}")
print(f"Intercept: {theta[0]}")

plt.scatter(y_test, y_pred)
plt.plot([min(y_test), max(y_test)], [min(y_pred), max(y_pred)], color='red')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.title('Actual vs Predicted Values')
plt.show()
# Out:
# Iteration 1: Cost 103384.1683
# Iteration 101: Cost 13848.1250
# Iteration 201: Cost 1872.9211
# Iteration 301: Cost 264.3562
# Iteration 401: Cost 47.1279
# Iteration 501: Cost 17.2741
# Iteration 601: Cost 12.8552
# Iteration 701: Cost 11.9777
# Iteration 801: Cost 11.6443
# Iteration 901: Cost 11.4292
# Mean Squared Error: 21.24
# R-Squared: 0.93
# Coefficients: [-11.9154304   -5.03322657   0.89523318  -1.36039579]
# Intercept: 454.3474304003996

# %%
#iteration 2
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=0)

X_train = np.c_[np.ones(X_train.shape[0]), X_train]
X_test = np.c_[np.ones(X_test.shape[0]), X_test]


def gradient_descent(X, y, learning_rate=0.01, iterations=1000):
    m = X.shape[0]
    n = X.shape[1]
    theta = np.zeros(n)
    for i in range(iterations):
        y_pred = np.dot(X, theta)
        error = y_pred - y
        gradient = (1/m) * np.dot(X.T, error)
        theta -= learning_rate * gradient
        if i % 100 == 0:  
            cost = (1/(2*m)) * np.dot(error.T, error)
            print(f"Iteration {i+1}: Cost {cost:.4f}")
    return theta

learning_rate = 0.01
iterations = 1000
theta = gradient_descent(X_train, y_train, learning_rate, iterations)


y_pred = np.dot(X_test, theta)

mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"Mean Squared Error: {mse:.2f}")
print(f"R-Squared: {r2:.2f}")

print(f"Coefficients: {theta[1:]}")
print(f"Intercept: {theta[0]}")

plt.scatter(y_test, y_pred)
plt.plot([min(y_test), max(y_test)], [min(y_pred), max(y_pred)], color='red')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.title('Actual vs Predicted Values')
plt.show()
# Out:
# Iteration 1: Cost 103344.1484
# Iteration 101: Cost 13850.3003
# Iteration 201: Cost 1869.7104
# Iteration 301: Cost 262.9730
# Iteration 401: Cost 46.8428
# Iteration 501: Cost 17.3424
# Iteration 601: Cost 12.9921
# Iteration 701: Cost 12.0981
# Iteration 801: Cost 11.7286
# Iteration 901: Cost 11.4768
# Mean Squared Error: 22.63
# R-Squared: 0.92
# Coefficients: [-11.48804836  -5.33972156   1.03173274  -1.2615977 ]
# Intercept: 454.3517826824513

# %%
#iteration 2
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=42)

X_train = np.c_[np.ones(X_train.shape[0]), X_train]
X_test = np.c_[np.ones(X_test.shape[0]), X_test]


def gradient_descent(X, y, learning_rate=0.01, iterations=1000):
    m = X.shape[0]
    n = X.shape[1]
    theta = np.zeros(n)
    for i in range(iterations):
        y_pred = np.dot(X, theta)
        error = y_pred - y
        gradient = (1/m) * np.dot(X.T, error)
        theta -= learning_rate * gradient
        if i % 100 == 0:  
            cost = (1/(2*m)) * np.dot(error.T, error)
            print(f"Iteration {i+1}: Cost {cost:.4f}")
    return theta

learning_rate = 0.01
iterations = 1000
theta = gradient_descent(X_train, y_train, learning_rate, iterations)


y_pred = np.dot(X_test, theta)

mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"Mean Squared Error: {mse:.2f}")
print(f"R-Squared: {r2:.2f}")

print(f"Coefficients: {theta[1:]}")
print(f"Intercept: {theta[0]}")

plt.scatter(y_test, y_pred)
plt.plot([min(y_test), max(y_test)], [min(y_pred), max(y_pred)], color='red')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.title('Actual vs Predicted Values')
plt.show()
# Out:
# Iteration 1: Cost 103409.5114
# Iteration 101: Cost 13847.0460
# Iteration 201: Cost 1871.8761
# Iteration 301: Cost 263.7402
# Iteration 401: Cost 46.8069
# Iteration 501: Cost 17.0959
# Iteration 601: Cost 12.7421
# Iteration 701: Cost 11.8970
# Iteration 801: Cost 11.5825
# Iteration 901: Cost 11.3801
# Mean Squared Error: 21.54
# R-Squared: 0.93
# Coefficients: [-11.97509671  -4.96262905   0.93248663  -1.35787031]
# Intercept: 454.3533264863954

# %%
#iteration 3
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)

X_train = np.c_[np.ones(X_train.shape[0]), X_train]
X_test = np.c_[np.ones(X_test.shape[0]), X_test]


def gradient_descent(X, y, learning_rate=0.01, iterations=1000):
    m = X.shape[0]
    n = X.shape[1]
    theta = np.zeros(n)
    for i in range(iterations):
        y_pred = np.dot(X, theta)
        error = y_pred - y
        gradient = (1/m) * np.dot(X.T, error)
        theta -= learning_rate * gradient
        if i % 100 == 0:  
            cost = (1/(2*m)) * np.dot(error.T, error)
            print(f"Iteration {i+1}: Cost {cost:.4f}")
    return theta

learning_rate = 0.01
iterations = 1000
theta = gradient_descent(X_train, y_train, learning_rate, iterations)


y_pred = np.dot(X_test, theta)

mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"Mean Squared Error: {mse:.2f}")
print(f"R-Squared: {r2:.2f}")

print(f"Coefficients: {theta[1:]}")
print(f"Intercept: {theta[0]}")

plt.scatter(y_test, y_pred)
plt.plot([min(y_test), max(y_test)], [min(y_pred), max(y_pred)], color='red')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.title('Actual vs Predicted Values')
plt.show()
# Out:
# Iteration 1: Cost 103353.4798
# Iteration 101: Cost 13847.1483
# Iteration 201: Cost 1870.2144
# Iteration 301: Cost 263.4658
# Iteration 401: Cost 47.1282
# Iteration 501: Cost 17.5373
# Iteration 601: Cost 13.1626
# Iteration 701: Cost 12.2686
# Iteration 801: Cost 11.9059
# Iteration 901: Cost 11.6618
# Mean Squared Error: 22.59
# R-Squared: 0.92
# Coefficients: [-11.34361303  -5.49405945   1.05103463  -1.28841324]
# Intercept: 454.3260771275099

# %%
#iteration 3
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=42)

X_train = np.c_[np.ones(X_train.shape[0]), X_train]
X_test = np.c_[np.ones(X_test.shape[0]), X_test]


def gradient_descent(X, y, learning_rate=0.01, iterations=1000):
    m = X.shape[0]
    n = X.shape[1]
    theta = np.zeros(n)
    for i in range(iterations):
        y_pred = np.dot(X, theta)
        error = y_pred - y
        gradient = (1/m) * np.dot(X.T, error)
        theta -= learning_rate * gradient
        if i % 100 == 0:  
            cost = (1/(2*m)) * np.dot(error.T, error)
            print(f"Iteration {i+1}: Cost {cost:.4f}")
    return theta

learning_rate = 0.01
iterations = 1000
theta = gradient_descent(X_train, y_train, learning_rate, iterations)


y_pred = np.dot(X_test, theta)

mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"Mean Squared Error: {mse:.2f}")
print(f"R-Squared: {r2:.2f}")

print(f"Coefficients: {theta[1:]}")
print(f"Intercept: {theta[0]}")

plt.scatter(y_test, y_pred)
plt.plot([min(y_test), max(y_test)], [min(y_pred), max(y_pred)], color='red')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.title('Actual vs Predicted Values')
plt.show()
# Out:
# Iteration 1: Cost 103369.4299
# Iteration 101: Cost 13846.8937
# Iteration 201: Cost 1869.8444
# Iteration 301: Cost 262.4189
# Iteration 401: Cost 45.9606
# Iteration 501: Cost 16.4710
# Iteration 601: Cost 12.2178
# Iteration 701: Cost 11.4228
# Iteration 801: Cost 11.1374
# Iteration 901: Cost 10.9545
# Mean Squared Error: 22.13
# R-Squared: 0.92
# Coefficients: [-12.23058752  -4.84060659   0.85500866  -1.43013896]
# Intercept: 454.32516628208793
